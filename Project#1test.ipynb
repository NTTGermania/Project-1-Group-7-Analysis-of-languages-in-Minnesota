# %%
import pandas as pd 
import numpy as np

# %%
# File to load
primary_home_language_2007 = "data/2006-2007 Primary Home Language Totals.csv"

primary_home_language_2007_df = pd.read_csv(primary_home_language_2007)
primary_home_language_2007_df
# Out:
#      sub_cde dat_yer  dst_num  dst_tye                         district  \
# 0          F   06-07        1        1    AITKIN PUBLIC SCHOOL DISTRICT
# 1          F   06-07        1        1    AITKIN PUBLIC SCHOOL DISTRICT
# 2          F   06-07        1        3  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          F   06-07        1        3  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          F   06-07        1        3  MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...      ...     ...      ...      ...                              ...
# 3479       F   06-07     9999       99                 Statewide Totals
# 3480       F   06-07     9999       99                 Statewide Totals
# 3481       F   06-07     9999       99                 Statewide Totals
# 3482       F   06-07     9999       99                 Statewide Totals
# 3483       F   06-07     9999       99                 Statewide Totals
#
#              language  homprm_lng  k12count  d_county    county eco_dev  \
# 0             ENGLISH          11      1318       1.0    AITKIN      03
# 1             SPANISH          45         2       1.0    AITKIN      03
# 2              AFGHAN          60         3      27.0  HENNEPIN      11
# 3           AFRIKAANS           1         4      27.0  HENNEPIN      11
# 4     AMERICAN INDIAN           6         1      27.0  HENNEPIN      11
# ...               ...         ...       ...       ...       ...     ...
# 3479            UZBEK          96         2       NaN       NaN     NaN
# 3480       VIETNAMESE          51      3215       NaN       NaN     NaN
# 3481            WOLOF          94         9       NaN       NaN     NaN
# 3482              YAO          61         3       NaN       NaN     NaN
# 3483           YORUBA          75       257       NaN       NaN     NaN
#
#       stratanum                                       strata
# 0           4.0  Outstate - Enrollment between 1000 and 1999
# 1           4.0  Outstate - Enrollment between 1000 and 1999
# 2           1.0                   Minneapolis and Saint Paul
# 3           1.0                   Minneapolis and Saint Paul
# 4           1.0                   Minneapolis and Saint Paul
# ...         ...                                          ...
# 3479        NaN                                          NaN
# 3480        NaN                                          NaN
# 3481        NaN                                          NaN
# 3482        NaN                                          NaN
# 3483        NaN                                          NaN
#
# [3484 rows x 13 columns]
