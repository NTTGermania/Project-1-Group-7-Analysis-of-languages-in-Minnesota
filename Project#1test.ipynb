# %% [markdown]
# # Project 1: Languages Spoken in the Homes of Minnesota Public School Students
#
# ## Contributors: Sam Espe, Yameena Khan, Maryam Osman, Nhan Tran (Group 7)
#
# ## Notebook 1: Data Cleaning and Exploration

# %%
# Import dependencies

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read and clean data: read in CSVs, rename columns, drop unnecessary columns, split off yearly summary

# %%
primary_home_language_2007 = "data/2006-2007 Primary Home Language Totals.csv"
primary_home_language_2007_df = pd.read_csv(primary_home_language_2007)
primary_home_language_2007_rename_df = primary_home_language_2007_df.rename(columns = { "dat_yer" : "School Year", "district" : "District Name", "language" : "Language Name", "homprm_lng": "Home Primary Language", "k12count" : "Student Count" , "county" : "County Name", "stratanum" : "Strata Number", "strata" : "Strata Name"})
primary_home_language_2007_summary_df  = primary_home_language_2007_rename_df.drop(columns = ["sub_cde","dst_num","dst_tye","d_county","eco_dev"])
primary_home_language_2007_summary_df
# Out:
#      School Year                    District Name    Language Name  \
# 0          06-07    AITKIN PUBLIC SCHOOL DISTRICT          ENGLISH
# 1          06-07    AITKIN PUBLIC SCHOOL DISTRICT          SPANISH
# 2          06-07  MINNEAPOLIS PUBLIC SCHOOL DIST.           AFGHAN
# 3          06-07  MINNEAPOLIS PUBLIC SCHOOL DIST.        AFRIKAANS
# 4          06-07  MINNEAPOLIS PUBLIC SCHOOL DIST.  AMERICAN INDIAN
# ...          ...                              ...              ...
# 3479       06-07                 Statewide Totals            UZBEK
# 3480       06-07                 Statewide Totals       VIETNAMESE
# 3481       06-07                 Statewide Totals            WOLOF
# 3482       06-07                 Statewide Totals              YAO
# 3483       06-07                 Statewide Totals           YORUBA
#
#       Home Primary Language  Student Count County Name  Strata Number  \
# 0                        11           1318      AITKIN            4.0
# 1                        45              2      AITKIN            4.0
# 2                        60              3    HENNEPIN            1.0
# 3                         1              4    HENNEPIN            1.0
# 4                         6              1    HENNEPIN            1.0
# ...                     ...            ...         ...            ...
# 3479                     96              2         NaN            NaN
# 3480                     51           3215         NaN            NaN
# 3481                     94              9         NaN            NaN
# 3482                     61              3         NaN            NaN
# 3483                     75            257         NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 3479                                          NaN
# 3480                                          NaN
# 3481                                          NaN
# 3482                                          NaN
# 3483                                          NaN
#
# [3484 rows x 8 columns]

# %%
primary_home_language_2007_final_df = primary_home_language_2007_summary_df[~primary_home_language_2007_summary_df["Strata Number"].isna()]
primary_home_language_2007_final_df
# Out:
#      School Year                       District Name    Language Name  \
# 0          06-07       AITKIN PUBLIC SCHOOL DISTRICT          ENGLISH
# 1          06-07       AITKIN PUBLIC SCHOOL DISTRICT          SPANISH
# 2          06-07     MINNEAPOLIS PUBLIC SCHOOL DIST.           AFGHAN
# 3          06-07     MINNEAPOLIS PUBLIC SCHOOL DIST.        AFRIKAANS
# 4          06-07     MINNEAPOLIS PUBLIC SCHOOL DIST.  AMERICAN INDIAN
# ...          ...                                 ...              ...
# 3382       06-07  CENTRAL MINNESOTA JT. POWERS DIST.          ENGLISH
# 3383       06-07  CENTRAL MINNESOTA JT. POWERS DIST.          SPANISH
# 3384       06-07           NORTHLAND LEARNING CENTER          ENGLISH
# 3385       06-07         BENTON-STEARNS ED. DISTRICT          ENGLISH
# 3386       06-07        MID STATE EDUCATION DISTRICT          ENGLISH
#
#       Home Primary Language  Student Count  County Name  Strata Number  \
# 0                        11           1318       AITKIN            4.0
# 1                        45              2       AITKIN            4.0
# 2                        60              3     HENNEPIN            1.0
# 3                         1              4     HENNEPIN            1.0
# 4                         6              1     HENNEPIN            1.0
# ...                     ...            ...          ...            ...
# 3382                     11             63      STEARNS            6.0
# 3383                     45              1      STEARNS            6.0
# 3384                     11            117  SAINT LOUIS            6.0
# 3385                     11             29      STEARNS            6.0
# 3386                     11             31     MORRISON            6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 3382          Outstate - Enrollment less than 500
# 3383          Outstate - Enrollment less than 500
# 3384          Outstate - Enrollment less than 500
# 3385          Outstate - Enrollment less than 500
# 3386          Outstate - Enrollment less than 500
#
# [3387 rows x 8 columns]

# %%
language_summary_2007_df = primary_home_language_2007_summary_df[primary_home_language_2007_summary_df["Strata Number"].isna()]
language_summary_2007_final_df = language_summary_2007_df.drop(columns = {"County Name", "Strata Number", "Strata Name"})
language_summary_2007_final_df
# Out:
#      School Year     District Name    Language Name  Home Primary Language  \
# 3387       06-07  Statewide Totals          ADANGME                     83
# 3388       06-07  Statewide Totals           AFGHAN                     60
# 3389       06-07  Statewide Totals        AFRIKAANS                      1
# 3390       06-07  Statewide Totals         ALBANIAN                     72
# 3391       06-07  Statewide Totals  AMERICAN INDIAN                      6
# ...          ...               ...              ...                    ...
# 3479       06-07  Statewide Totals            UZBEK                     96
# 3480       06-07  Statewide Totals       VIETNAMESE                     51
# 3481       06-07  Statewide Totals            WOLOF                     94
# 3482       06-07  Statewide Totals              YAO                     61
# 3483       06-07  Statewide Totals           YORUBA                     75
#
#       Student Count
# 3387            121
# 3388             21
# 3389            525
# 3390             42
# 3391             27
# ...             ...
# 3479              2
# 3480           3215
# 3481              9
# 3482              3
# 3483            257
#
# [97 rows x 5 columns]

# %%
primary_home_language_2008 = "data/2007-2008 Primary Home Language Totals.csv"
primary_home_language_2008_df = pd.read_csv(primary_home_language_2008)
primary_home_language_2008_rename_df = primary_home_language_2008_df.rename(columns = { "fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name", "homePrimaryLanguage": "Home Primary Language", "enrollments" : "Student Count" , "CountyName" : "County Name", "strata" : "Strata Number", "startaName" : "Strata Name"})
primary_home_language_2008_summary_df = primary_home_language_2008_rename_df.drop(columns = {"districtNumber", "districtType", "eco_dev_rgn", "countyCode"})

# %%
primary_home_language_2008_final_df = primary_home_language_2008_summary_df[~primary_home_language_2008_summary_df["Strata Number"].isna()]
primary_home_language_2008_final_df
# Out:
#      School Year                        District Name  \
# 0          07-08  AITKIN PUBLIC SCHOOL DISTRICT
# 1          07-08  AITKIN PUBLIC SCHOOL DISTRICT
# 2          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                                  ...
# 3419       07-08  VALLEY CROSSING COMMUNITY SCHOOL
# 3420       07-08  CENTRAL MINNESOTA JT. POWERS DIST.
# 3421       07-08  NORTHLAND LEARNING CENTER
# 3422       07-08  BENTON-STEARNS ED. DISTRICT
# 3423       07-08  MID STATE EDUCATION DISTRICT
#
#                        Language Name  Home Primary Language  Student Count  \
# 0     ENGLISH                                            11           1283
# 1     SPANISH                                            45              3
# 2     HINDI                                              19             75
# 3     CHINESE                                             7             54
# 4     AFRIKAANS                                           1              3
# ...                              ...                    ...            ...
# 3419  HMONG                                              20              8
# 3420  ENGLISH                                            11             41
# 3421  ENGLISH                                            11             97
# 3422  ENGLISH                                            11             34
# 3423  ENGLISH                                            11             29
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 3419  Washington                                               2.0
# 3420  Stearns                                                  6.0
# 3421  St. Louis                                                6.0
# 3422  Stearns                                                  6.0
# 3423  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 3419         County Metro Area excluding MPLS/STP
# 3420          Outstate - Enrollment less than 500
# 3421          Outstate - Enrollment less than 500
# 3422          Outstate - Enrollment less than 500
# 3423          Outstate - Enrollment less than 500
#
# [3424 rows x 8 columns]

# %%
language_summary_2008_df = primary_home_language_2008_summary_df[primary_home_language_2008_summary_df["Strata Number"].isna()]
language_summary_2008_final_df = language_summary_2008_df.drop(columns = {"County Name", "Strata Number", "Strata Name"})
language_summary_2008_final_df
# Out:
#      School Year                        District Name  \
# 3424       07-08  STATEWIDE
# 3425       07-08  STATEWIDE
# 3426       07-08  STATEWIDE
# 3427       07-08  STATEWIDE
# 3428       07-08  STATEWIDE
# ...          ...                                  ...
# 3510       07-08  STATEWIDE
# 3511       07-08  STATEWIDE
# 3512       07-08  STATEWIDE
# 3513       07-08  STATEWIDE
# 3514       07-08  STATEWIDE
#
#                                           Language Name  \
# 3424                     SWEDISH
# 3425                     ROMANIAN
# 3426                     ARABIC
# 3427                     HAUSA
# 3428                     SLOVAK
# ...                                                 ...
# 3510          RWANDA/SOTHO/ZULU
# 3511                     OROMO
# 3512  BALINESE/JAVANESE/SUNDANESE
# 3513                     TIBETAN
# 3514                     CAMBODIAN
#
#       Home Primary Language  Student Count
# 3424                     46             80
# 3425                     39            140
# 3426                      2           1301
# 3427                     66             33
# 3428                     43             25
# ...                     ...            ...
# 3510                     93             18
# 3511                     74            950
# 3512                     86             13
# 3513                     73            159
# 3514                      5           1628
#
# [91 rows x 5 columns]

# %%
primary_home_language_2009 = "data/2008-2009 Primary Home Language Totals.csv"
primary_home_language_2009_df = pd.read_csv(primary_home_language_2009)
primary_home_language_2009_rename_df = primary_home_language_2008_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name","homePrimaryLanguage": "Home Primary Language", "enrollments" : "Student Count" , "county" : "County", "CountyName": "County Name", "startaName" : "Strata Name", "strata" : "Strata Number"})
primary_home_language_2009_summary_df = primary_home_language_2009_rename_df.drop(columns = {"districtNumber", "districtType", "eco_dev_rgn", "countyCode"})
primary_home_language_2009_summary_df
# Out:
#      School Year                        District Name  \
# 0          07-08  AITKIN PUBLIC SCHOOL DISTRICT
# 1          07-08  AITKIN PUBLIC SCHOOL DISTRICT
# 2          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                                  ...
# 3510       07-08  STATEWIDE
# 3511       07-08  STATEWIDE
# 3512       07-08  STATEWIDE
# 3513       07-08  STATEWIDE
# 3514       07-08  STATEWIDE
#
#                                           Language Name  \
# 0                        ENGLISH
# 1                        SPANISH
# 2                        HINDI
# 3                        CHINESE
# 4                        AFRIKAANS
# ...                                                 ...
# 3510          RWANDA/SOTHO/ZULU
# 3511                     OROMO
# 3512  BALINESE/JAVANESE/SUNDANESE
# 3513                     TIBETAN
# 3514                     CAMBODIAN
#
#       Home Primary Language  Student Count  \
# 0                        11           1283
# 1                        45              3
# 2                        19             75
# 3                         7             54
# 4                         1              3
# ...                     ...            ...
# 3510                     93             18
# 3511                     74            950
# 3512                     86             13
# 3513                     73            159
# 3514                      5           1628
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 3510  UNKNOWN                                                  NaN
# 3511  UNKNOWN                                                  NaN
# 3512  UNKNOWN                                                  NaN
# 3513  UNKNOWN                                                  NaN
# 3514  UNKNOWN                                                  NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 3510                                          NaN
# 3511                                          NaN
# 3512                                          NaN
# 3513                                          NaN
# 3514                                          NaN
#
# [3515 rows x 8 columns]

# %%
primary_home_language_2009_final_df = primary_home_language_2009_summary_df[~primary_home_language_2009_summary_df['Strata Number'].isnull()]
primary_home_language_2009_final_df
# Out:
#      School Year                        District Name  \
# 0          07-08  AITKIN PUBLIC SCHOOL DISTRICT
# 1          07-08  AITKIN PUBLIC SCHOOL DISTRICT
# 2          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          07-08  MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                                  ...
# 3419       07-08  VALLEY CROSSING COMMUNITY SCHOOL
# 3420       07-08  CENTRAL MINNESOTA JT. POWERS DIST.
# 3421       07-08  NORTHLAND LEARNING CENTER
# 3422       07-08  BENTON-STEARNS ED. DISTRICT
# 3423       07-08  MID STATE EDUCATION DISTRICT
#
#                        Language Name  Home Primary Language  Student Count  \
# 0     ENGLISH                                            11           1283
# 1     SPANISH                                            45              3
# 2     HINDI                                              19             75
# 3     CHINESE                                             7             54
# 4     AFRIKAANS                                           1              3
# ...                              ...                    ...            ...
# 3419  HMONG                                              20              8
# 3420  ENGLISH                                            11             41
# 3421  ENGLISH                                            11             97
# 3422  ENGLISH                                            11             34
# 3423  ENGLISH                                            11             29
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 3419  Washington                                               2.0
# 3420  Stearns                                                  6.0
# 3421  St. Louis                                                6.0
# 3422  Stearns                                                  6.0
# 3423  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 3419         County Metro Area excluding MPLS/STP
# 3420          Outstate - Enrollment less than 500
# 3421          Outstate - Enrollment less than 500
# 3422          Outstate - Enrollment less than 500
# 3423          Outstate - Enrollment less than 500
#
# [3424 rows x 8 columns]

# %%
language_summary_2009_df = primary_home_language_2009_summary_df[primary_home_language_2009_summary_df["Strata Number"].isna()]
language_summary_2009_final_df = language_summary_2009_df.drop(columns = {"County Name", "Strata Number", "Strata Name"})
language_summary_2009_final_df
# Out:
#      School Year                        District Name  \
# 3424       07-08  STATEWIDE
# 3425       07-08  STATEWIDE
# 3426       07-08  STATEWIDE
# 3427       07-08  STATEWIDE
# 3428       07-08  STATEWIDE
# ...          ...                                  ...
# 3510       07-08  STATEWIDE
# 3511       07-08  STATEWIDE
# 3512       07-08  STATEWIDE
# 3513       07-08  STATEWIDE
# 3514       07-08  STATEWIDE
#
#                                           Language Name  \
# 3424                     SWEDISH
# 3425                     ROMANIAN
# 3426                     ARABIC
# 3427                     HAUSA
# 3428                     SLOVAK
# ...                                                 ...
# 3510          RWANDA/SOTHO/ZULU
# 3511                     OROMO
# 3512  BALINESE/JAVANESE/SUNDANESE
# 3513                     TIBETAN
# 3514                     CAMBODIAN
#
#       Home Primary Language  Student Count
# 3424                     46             80
# 3425                     39            140
# 3426                      2           1301
# 3427                     66             33
# 3428                     43             25
# ...                     ...            ...
# 3510                     93             18
# 3511                     74            950
# 3512                     86             13
# 3513                     73            159
# 3514                      5           1628
#
# [91 rows x 5 columns]

# %%
primary_home_language_2010 = "data/2009-2010 Primary Home Language Totals.csv"
primary_home_language_2010_df = pd.read_csv(primary_home_language_2010)
primary_home_language_2010_rename_df = primary_home_language_2010_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name","homePrimaryLanguage": "Home Primary Language", "enrollments" : "Student Count" , "CountyName" : "County Name", "startaName" : "Strata Name", "strata" : "Strata Number"})
primary_home_language_2010_summary_df = primary_home_language_2010_rename_df.drop(columns = {"districtNumber", "districtType", "eco_dev_rgn", "countyCode"})
primary_home_language_2010_summary_df
# Out:
#      School Year                    District Name  \
# 0          09-10    AITKIN PUBLIC SCHOOL DISTRICT
# 1          09-10    AITKIN PUBLIC SCHOOL DISTRICT
# 2          09-10    AITKIN PUBLIC SCHOOL DISTRICT
# 3          09-10  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          09-10  MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                              ...
# 3642       09-10                        STATEWIDE
# 3643       09-10                        STATEWIDE
# 3644       09-10                        STATEWIDE
# 3645       09-10                        STATEWIDE
# 3646       09-10                        STATEWIDE
#
#                        Language Name  Home Primary Language  Student Count  \
# 0     ENGLISH                                            11           1268
# 1     RUSSIAN                                            40              1
# 2     SPANISH                                            45              2
# 3     TURKISH                                            48              5
# 4     NORWEGIAN                                          34              2
# ...                              ...                    ...            ...
# 3642  SWEDISH                                            46             75
# 3643  DANISH                                              9             39
# 3644  MONGOLIAN                                          25              9
# 3645  GAELIC                                             16              3
# 3646  TURKISH                                            48             48
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Aitkin                                                   4.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 3642  UNKNOWN                                                  NaN
# 3643  UNKNOWN                                                  NaN
# 3644  UNKNOWN                                                  NaN
# 3645  UNKNOWN                                                  NaN
# 3646  UNKNOWN                                                  NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 3642                                          NaN
# 3643                                          NaN
# 3644                                          NaN
# 3645                                          NaN
# 3646                                          NaN
#
# [3647 rows x 8 columns]

# %%
primary_home_language_2010_final_df = primary_home_language_2010_summary_df[~primary_home_language_2010_summary_df["Strata Number"].isna()]
primary_home_language_2010_final_df
# Out:
#      School Year                       District Name  \
# 0          09-10       AITKIN PUBLIC SCHOOL DISTRICT
# 1          09-10       AITKIN PUBLIC SCHOOL DISTRICT
# 2          09-10       AITKIN PUBLIC SCHOOL DISTRICT
# 3          09-10     MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          09-10     MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                                 ...
# 3546       09-10  CENTRAL MINNESOTA JT. POWERS DIST.
# 3547       09-10           NORTHLAND LEARNING CENTER
# 3548       09-10    RUM RIVER SPECIAL EDUCATION COOP
# 3549       09-10         BENTON-STEARNS ED. DISTRICT
# 3550       09-10        MID STATE EDUCATION DISTRICT
#
#                        Language Name  Home Primary Language  Student Count  \
# 0     ENGLISH                                            11           1268
# 1     RUSSIAN                                            40              1
# 2     SPANISH                                            45              2
# 3     TURKISH                                            48              5
# 4     NORWEGIAN                                          34              2
# ...                              ...                    ...            ...
# 3546  ENGLISH                                            11             48
# 3547  ENGLISH                                            11             87
# 3548  ENGLISH                                            11             68
# 3549  ENGLISH                                            11             35
# 3550  ENGLISH                                            11             28
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Aitkin                                                   4.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 3546  Stearns                                                  6.0
# 3547  St. Louis                                                6.0
# 3548  Isanti                                                   6.0
# 3549  Stearns                                                  6.0
# 3550  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 3546          Outstate - Enrollment less than 500
# 3547          Outstate - Enrollment less than 500
# 3548          Outstate - Enrollment less than 500
# 3549          Outstate - Enrollment less than 500
# 3550          Outstate - Enrollment less than 500
#
# [3551 rows x 8 columns]

# %%
language_summary_2010_df = primary_home_language_2010_summary_df[primary_home_language_2010_summary_df["Strata Number"].isna()]
language_summary_2010_final_df = language_summary_2010_df.drop(columns = {"County Name", "Strata Number", "Strata Name"})
language_summary_2010_final_df
# Out:
#      School Year District Name                   Language Name  \
# 3551       09-10     STATEWIDE    BERBER/ KABYLE
# 3552       09-10     STATEWIDE  CHINESE
# 3553       09-10     STATEWIDE  CZECH
# 3554       09-10     STATEWIDE  FINNISH
# 3555       09-10     STATEWIDE  SINGHALESE
# ...          ...           ...                             ...
# 3642       09-10     STATEWIDE  SWEDISH
# 3643       09-10     STATEWIDE  DANISH
# 3644       09-10     STATEWIDE  MONGOLIAN
# 3645       09-10     STATEWIDE  GAELIC
# 3646       09-10     STATEWIDE  TURKISH
#
#       Home Primary Language  Student Count
# 3551                     78              2
# 3552                      7           2000
# 3553                      4             25
# 3554                     14             53
# 3555                     58             12
# ...                     ...            ...
# 3642                     46             75
# 3643                      9             39
# 3644                     25              9
# 3645                     16              3
# 3646                     48             48
#
# [96 rows x 5 columns]

# %%
primary_home_language_2011 = "data/2010_2011 Primary Home Language Totals.csv"
primary_home_language_2011_df = pd.read_csv(primary_home_language_2011)
primary_home_language_2011_rename_df = primary_home_language_2011_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name","homePrimaryLanguage": "Home Primary Language", "enrollments" : "Student Count" , "CountyName": "County Name", "strataName" : "Strata Name", "strata" : "Strata Number"})
primary_home_language_2011_summary_df = primary_home_language_2011_rename_df.drop(columns = {"districtNumber", "districtType", "eco_dev_rgn", "countyCode"})
primary_home_language_2011_summary_df
# Out:
#      School Year                        District Name Language Name  \
# 0          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.           Amharic
# 1          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.            Arabic
# 2          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.           Bengali
# 3          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.           Bosnian
# 4          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.         Bulgarian
# ...          ...                                  ...           ...
# 4308         NaN                                  NaN           NaN
# 4309         NaN                                  NaN           NaN
# 4310         NaN                                  NaN           NaN
# 4311         NaN                                  NaN           NaN
# 4312         NaN                                  NaN           NaN
#
#       Home Primary Language  Student Count  \
# 0                      63.0           82.0
# 1                       2.0           58.0
# 2                      10.0           20.0
# 3                      41.0            9.0
# 4                      64.0            1.0
# ...                     ...            ...
# 4308                    NaN            NaN
# 4309                    NaN            NaN
# 4310                    NaN            NaN
# 4311                    NaN            NaN
# 4312                    NaN            NaN
#
#                                         County Name  Strata Number  \
# 0     Hennepin                                                 1.0
# 1     Hennepin                                                 1.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 4308                                            NaN            NaN
# 4309                                            NaN            NaN
# 4310                                            NaN            NaN
# 4311                                            NaN            NaN
# 4312                                            NaN            NaN
#
#                      Strata Name
# 0     Minneapolis and Saint Paul
# 1     Minneapolis and Saint Paul
# 2     Minneapolis and Saint Paul
# 3     Minneapolis and Saint Paul
# 4     Minneapolis and Saint Paul
# ...                          ...
# 4308                         NaN
# 4309                         NaN
# 4310                         NaN
# 4311                         NaN
# 4312                         NaN
#
# [4313 rows x 8 columns]

# %%
primary_home_language_2011_final_df = primary_home_language_2011_summary_df[~primary_home_language_2011_summary_df["Strata Number"].isna()]
primary_home_language_2011_final_df
# Out:
#      School Year                        District Name Language Name  \
# 0          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.           Amharic
# 1          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.            Arabic
# 2          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.           Bengali
# 3          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.           Bosnian
# 4          10-11  MINNEAPOLIS PUBLIC SCHOOL DIST.         Bulgarian
# ...          ...                                  ...           ...
# 3742       10-11  CENTRAL MINNESOTA JT. POWERS DIST.        English
# 3743       10-11  NORTHLAND LEARNING CENTER                 English
# 3744       10-11  RUM RIVER SPECIAL EDUCATION COOP          English
# 3745       10-11  BENTON-STEARNS ED. DISTRICT               English
# 3746       10-11  MID STATE EDUCATION DISTRICT              English
#
#       Home Primary Language  Student Count  \
# 0                      63.0           82.0
# 1                       2.0           58.0
# 2                      10.0           20.0
# 3                      41.0            9.0
# 4                      64.0            1.0
# ...                     ...            ...
# 3742                   11.0           55.0
# 3743                   11.0           84.0
# 3744                   11.0           60.0
# 3745                   11.0           28.0
# 3746                   11.0           37.0
#
#                                         County Name  Strata Number  \
# 0     Hennepin                                                 1.0
# 1     Hennepin                                                 1.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 3742  Stearns                                                  6.0
# 3743  St. Louis                                                6.0
# 3744  Isanti                                                   6.0
# 3745  Stearns                                                  6.0
# 3746  Morrison                                                 6.0
#
#                               Strata Name
# 0              Minneapolis and Saint Paul
# 1              Minneapolis and Saint Paul
# 2              Minneapolis and Saint Paul
# 3              Minneapolis and Saint Paul
# 4              Minneapolis and Saint Paul
# ...                                   ...
# 3742  Outstate - Enrollment less than 500
# 3743  Outstate - Enrollment less than 500
# 3744  Outstate - Enrollment less than 500
# 3745  Outstate - Enrollment less than 500
# 3746  Outstate - Enrollment less than 500
#
# [3747 rows x 8 columns]

# %%
language_summary_2011_df = primary_home_language_2011_summary_df[primary_home_language_2011_summary_df["Strata Number"].isna()]
language_summary_2011_final_df = language_summary_2011_df.drop(columns = {"County Name", "Strata Number", "Strata Name"})
language_summary_2011_final_df
# Out:
#      School Year                        District Name Language Name  \
# 3747       10-11  STATEWIDE                                 Adangme
# 3748       10-11  STATEWIDE                               Afrikaans
# 3749       10-11  STATEWIDE                                   Akan
# 3750       10-11  STATEWIDE                                Albanian
# 3751       10-11  STATEWIDE                                 Amharic
# ...          ...                                  ...           ...
# 4308         NaN                                  NaN           NaN
# 4309         NaN                                  NaN           NaN
# 4310         NaN                                  NaN           NaN
# 4311         NaN                                  NaN           NaN
# 4312         NaN                                  NaN           NaN
#
#       Home Primary Language  Student Count
# 3747                   83.0          222.0
# 3748                    1.0          162.0
# 3749                  156.0            1.0
# 3750                   72.0           46.0
# 3751                   63.0          890.0
# ...                     ...            ...
# 4308                    NaN            NaN
# 4309                    NaN            NaN
# 4310                    NaN            NaN
# 4311                    NaN            NaN
# 4312                    NaN            NaN
#
# [566 rows x 5 columns]

# %%
primary_home_language_2012 = "data/2011-2012 Primary Home Language Totals.csv"
primary_home_language_2012_df = pd.read_csv(primary_home_language_2012)
primary_home_language_2012_rename_df = primary_home_language_2012_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name","homePrimaryLanguage": "Home Primary Language", "enrollments" : "Student Count" , "CountyName": "County Name", "strataName" : "Strata Name", "strata" : "Strata Number"})
primary_home_language_2012_summary_df = primary_home_language_2012_rename_df.drop(columns = {"districtNumber", "districtType", "eco_dev_rgn", "countyCode"})
primary_home_language_2012_summary_df
# Out:
#      School Year                    District Name  \
# 0          11-12    AITKIN PUBLIC SCHOOL DISTRICT
# 1          11-12    AITKIN PUBLIC SCHOOL DISTRICT
# 2          11-12  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          11-12  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          11-12  MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                              ...
# 4287       11-12                        STATEWIDE
# 4288       11-12                        STATEWIDE
# 4289       11-12                        STATEWIDE
# 4290       11-12                        STATEWIDE
# 4291       11-12                        STATEWIDE
#
#                       Language Name  Home Primary Language  Student Count  \
# 0                           Spanish                     45              1
# 1                           English                     11           1243
# 2                          Estonian                     12              3
# 3                         Ukrainian                     49              5
# 4     Indonesian, Bahasa Indonesian                     32              8
# ...                             ...                    ...            ...
# 4287                       Turkman                     135              1
# 4288                         Urhobo                    384              1
# 4289                         Hebrew                     18             27
# 4290                         Rwanda                     93             15
# 4291            Swahili, Kiswahili                      70            676
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 4287  UNKNOWN                                                  NaN
# 4288  UNKNOWN                                                  NaN
# 4289  UNKNOWN                                                  NaN
# 4290  UNKNOWN                                                  NaN
# 4291  UNKNOWN                                                  NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4287                                          NaN
# 4288                                          NaN
# 4289                                          NaN
# 4290                                          NaN
# 4291                                          NaN
#
# [4292 rows x 8 columns]

# %%
primary_home_language_2012_final_df = primary_home_language_2012_summary_df[~primary_home_language_2012_summary_df["Strata Number"].isna()]
primary_home_language_2012_final_df
# Out:
#      School Year                       District Name  \
# 0          11-12       AITKIN PUBLIC SCHOOL DISTRICT
# 1          11-12       AITKIN PUBLIC SCHOOL DISTRICT
# 2          11-12     MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          11-12     MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          11-12     MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                                 ...
# 4077       11-12  CENTRAL MINNESOTA JT. POWERS DIST.
# 4078       11-12           NORTHLAND LEARNING CENTER
# 4079       11-12    RUM RIVER SPECIAL EDUCATION COOP
# 4080       11-12         BENTON-STEARNS ED. DISTRICT
# 4081       11-12        MID STATE EDUCATION DISTRICT
#
#                       Language Name  Home Primary Language  Student Count  \
# 0                           Spanish                     45              1
# 1                           English                     11           1243
# 2                          Estonian                     12              3
# 3                         Ukrainian                     49              5
# 4     Indonesian, Bahasa Indonesian                     32              8
# ...                             ...                    ...            ...
# 4077                        English                     11             49
# 4078                        English                     11             80
# 4079                        English                     11             53
# 4080                        English                     11             32
# 4081                        English                     11             46
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 4077  Stearns                                                  6.0
# 4078  St. Louis                                                6.0
# 4079  Isanti                                                   6.0
# 4080  Stearns                                                  6.0
# 4081  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4077          Outstate - Enrollment less than 500
# 4078          Outstate - Enrollment less than 500
# 4079          Outstate - Enrollment less than 500
# 4080          Outstate - Enrollment less than 500
# 4081          Outstate - Enrollment less than 500
#
# [4082 rows x 8 columns]

# %%
language_summary_2012_df = primary_home_language_2012_summary_df[primary_home_language_2012_summary_df["Strata Number"].isna()]
language_summary_2012_final_df = language_summary_2012_df.drop(columns = {"County Name", "Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2012_final_df
# Out:
#     School Year District Name        Language Name  Home Primary Language  \
# 0         11-12     STATEWIDE             Gujarati                    112
# 1         11-12     STATEWIDE             Kashmiri                    265
# 2         11-12     STATEWIDE              Marathi                    116
# 3         11-12     STATEWIDE                Czech                      4
# 4         11-12     STATEWIDE           Mano. Mah                     297
# ..          ...           ...                  ...                    ...
# 205       11-12     STATEWIDE             Turkman                     135
# 206       11-12     STATEWIDE               Urhobo                    384
# 207       11-12     STATEWIDE               Hebrew                     18
# 208       11-12     STATEWIDE               Rwanda                     93
# 209       11-12     STATEWIDE  Swahili, Kiswahili                      70
#
#      Student Count
# 0               52
# 1                1
# 2               26
# 3               20
# 4                3
# ..             ...
# 205              1
# 206              1
# 207             27
# 208             15
# 209            676
#
# [210 rows x 5 columns]

# %%
primary_home_language_2013 = "data/2012-13 Primary Home Language Totals.csv"
primary_home_language_2013_df = pd.read_csv(primary_home_language_2013)
primary_home_language_2013_rename_df = primary_home_language_2013_df.rename(columns = {"Fiscal Year" : "School Year", "Strata" : "Strata Number", "Enrollments" : "Student Count"})
primary_home_language_2013_summary_df =  primary_home_language_2013_rename_df.drop(columns  = {"District Number","District Type", "County Code", "Economic Development Region"})
primary_home_language_2013_summary_df
# Out:
#            School Year                       District Name Language Name  \
# 0                12-13       AITKIN PUBLIC SCHOOL DISTRICT       English
# 1                12-13  MINNEAPOLIS PUBLIC SCHOOL DISTRICT         Hmong
# 2                12-13  MINNEAPOLIS PUBLIC SCHOOL DISTRICT       Russian
# 3                12-13  MINNEAPOLIS PUBLIC SCHOOL DISTRICT        Somali
# 4                12-13  MINNEAPOLIS PUBLIC SCHOOL DISTRICT        French
# ...                ...                                 ...           ...
# 4534             12-13                           STATEWIDE           Dei
# 4535             12-13                           STATEWIDE        Dakota
# 4536  End of Worksheet                                 NaN           NaN
# 4537               NaN                                 NaN           NaN
# 4538               NaN                                 NaN           NaN
#
#       Home Primary Language  Student Count  \
# 0                      11.0         1266.0
# 1                      20.0         1401.0
# 2                      40.0           20.0
# 3                      69.0         2535.0
# 4                      15.0           89.0
# ...                     ...            ...
# 4534                  218.0            1.0
# 4535                    8.0            7.0
# 4536                    NaN            NaN
# 4537                    NaN            NaN
# 4538                    NaN            NaN
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Hennepin                                                 1.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 4534  UNKNOWN                                                  NaN
# 4535  UNKNOWN                                                  NaN
# 4536                                            NaN            NaN
# 4537                                            NaN            NaN
# 4538                                            NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1                      Minneapolis and Saint Paul
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4534                                          NaN
# 4535                                          NaN
# 4536                                          NaN
# 4537                                          NaN
# 4538                                          NaN
#
# [4539 rows x 8 columns]

# %%
primary_home_language_2013_final_df = primary_home_language_2013_summary_df[~primary_home_language_2013_summary_df["Strata Number"].isna()]
primary_home_language_2013_final_df
# Out:
#      School Year                          District Name Language Name  \
# 0          12-13          AITKIN PUBLIC SCHOOL DISTRICT       English
# 1          12-13     MINNEAPOLIS PUBLIC SCHOOL DISTRICT         Hmong
# 2          12-13     MINNEAPOLIS PUBLIC SCHOOL DISTRICT       Russian
# 3          12-13     MINNEAPOLIS PUBLIC SCHOOL DISTRICT        Somali
# 4          12-13     MINNEAPOLIS PUBLIC SCHOOL DISTRICT        French
# ...          ...                                    ...           ...
# 4301       12-13  CENTRAL MINNESOTA JT. POWERS DISTRICT       English
# 4302       12-13              NORTHLAND LEARNING CENTER       English
# 4303       12-13       RUM RIVER SPECIAL EDUCATION COOP       English
# 4304       12-13            BENTON-STEARNS ED. DISTRICT       English
# 4305       12-13           MID STATE EDUCATION DISTRICT       English
#
#       Home Primary Language  Student Count  \
# 0                      11.0         1266.0
# 1                      20.0         1401.0
# 2                      40.0           20.0
# 3                      69.0         2535.0
# 4                      15.0           89.0
# ...                     ...            ...
# 4301                   11.0           35.0
# 4302                   11.0           83.0
# 4303                   11.0           67.0
# 4304                   11.0           38.0
# 4305                   11.0           45.0
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Hennepin                                                 1.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 4301  Stearns                                                  6.0
# 4302  St. Louis                                                6.0
# 4303  Isanti                                                   6.0
# 4304  Stearns                                                  6.0
# 4305  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1                      Minneapolis and Saint Paul
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4301          Outstate - Enrollment less than 500
# 4302          Outstate - Enrollment less than 500
# 4303          Outstate - Enrollment less than 500
# 4304          Outstate - Enrollment less than 500
# 4305          Outstate - Enrollment less than 500
#
# [4306 rows x 8 columns]

# %%
language_summary_2013_df = primary_home_language_2013_summary_df[primary_home_language_2013_summary_df["Strata Number"].isna()]
language_summary_2013_final_df = language_summary_2013_df.drop(columns = {"County Name", "Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2013_final_df
# Out:
#           School Year District Name       Language Name  \
# 0               12-13     STATEWIDE  Filipino, Pilipino
# 1               12-13     STATEWIDE               Tamil
# 2               12-13     STATEWIDE            Kalenjin
# 3               12-13     STATEWIDE               Wolof
# 4               12-13     STATEWIDE                 Edo
# ..                ...           ...                 ...
# 228             12-13     STATEWIDE                 Dei
# 229             12-13     STATEWIDE              Dakota
# 230  End of Worksheet           NaN                 NaN
# 231               NaN           NaN                 NaN
# 232               NaN           NaN                 NaN
#
#      Home Primary Language  Student Count
# 0                    126.0          207.0
# 1                    118.0          208.0
# 2                    260.0            5.0
# 3                     94.0           30.0
# 4                    139.0            4.0
# ..                     ...            ...
# 228                  218.0            1.0
# 229                    8.0            7.0
# 230                    NaN            NaN
# 231                    NaN            NaN
# 232                    NaN            NaN
#
# [233 rows x 5 columns]

# %%
primary_home_language_2014 = "data/2013-2014 Primary Home Language Totals.csv"
primary_home_language_2014_df = pd.read_csv(primary_home_language_2014)
primary_home_language_2014_rename_df = primary_home_language_2014_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name", "homePrimaryLanguage" : "Home Primary Language", "enrollments" : "Student Count", "Country Name" : "Country Name", "strata" : "Strata Number", "strataName" : "Strata Name"})
primary_home_language_2014_summary_df = primary_home_language_2014_rename_df.drop(columns = {"submissionCode", "districtType", "districtNumber", "countyCode", "CountyName", "eco_dev_rgn"})
primary_home_language_2014_summary_df
# Out:
#      School Year                    District Name  \
# 0          13-14    AITKIN PUBLIC SCHOOL DISTRICT
# 1          13-14  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 2          13-14  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          13-14  MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          13-14  MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                              ...
# 4686       13-14                        STATEWIDE
# 4687       13-14                        STATEWIDE
# 4688       13-14                        STATEWIDE
# 4689       13-14                        STATEWIDE
# 4690       13-14                        STATEWIDE
#
#                       Language Name  Home Primary Language  Student Count  \
# 0                           English                     11           1231
# 1        Cebuano, Visayan, Binisaya                     36             12
# 2                            Polish                     37              3
# 3     Indonesian, Bahasa Indonesian                     32              9
# 4                        Portuguese                     38              3
# ...                             ...                    ...            ...
# 4686                          Tonga                    168              4
# 4687                        Marathi                    116             67
# 4688                        Palauan                    336              1
# 4689                          Dutch                     33             85
# 4690                 Haitian Creole                     85             37
#
#       Strata Number                                  Strata Name
# 0               4.0  Outstate - Enrollment between 1000 and 1999
# 1               1.0                   Minneapolis and Saint Paul
# 2               1.0                   Minneapolis and Saint Paul
# 3               1.0                   Minneapolis and Saint Paul
# 4               1.0                   Minneapolis and Saint Paul
# ...             ...                                          ...
# 4686            NaN                                          NaN
# 4687            NaN                                          NaN
# 4688            NaN                                          NaN
# 4689            NaN                                          NaN
# 4690            NaN                                          NaN
#
# [4691 rows x 7 columns]

# %%
primary_home_language_2014_final_df = primary_home_language_2014_summary_df[~primary_home_language_2014_summary_df["Strata Number"].isna()]
primary_home_language_2014_final_df
# Out:
#      School Year                     District Name  \
# 0          13-14     AITKIN PUBLIC SCHOOL DISTRICT
# 1          13-14   MINNEAPOLIS PUBLIC SCHOOL DIST.
# 2          13-14   MINNEAPOLIS PUBLIC SCHOOL DIST.
# 3          13-14   MINNEAPOLIS PUBLIC SCHOOL DIST.
# 4          13-14   MINNEAPOLIS PUBLIC SCHOOL DIST.
# ...          ...                               ...
# 4450       13-14  SOUTHWEST METRO EDUCATIONAL COOP
# 4451       13-14  SOUTHWEST METRO EDUCATIONAL COOP
# 4452       13-14  SOUTHWEST METRO EDUCATIONAL COOP
# 4453       13-14       BENTON-STEARNS ED. DISTRICT
# 4454       13-14      MID STATE EDUCATION DISTRICT
#
#                       Language Name  Home Primary Language  Student Count  \
# 0                           English                     11           1231
# 1        Cebuano, Visayan, Binisaya                     36             12
# 2                            Polish                     37              3
# 3     Indonesian, Bahasa Indonesian                     32              9
# 4                        Portuguese                     38              3
# ...                             ...                    ...            ...
# 4450                  Lao, Laotian                      28              1
# 4451                        English                     11            244
# 4452                        Spanish                     45             25
# 4453                        English                     11             45
# 4454                        English                     11             47
#
#       Strata Number                                  Strata Name
# 0               4.0  Outstate - Enrollment between 1000 and 1999
# 1               1.0                   Minneapolis and Saint Paul
# 2               1.0                   Minneapolis and Saint Paul
# 3               1.0                   Minneapolis and Saint Paul
# 4               1.0                   Minneapolis and Saint Paul
# ...             ...                                          ...
# 4450            2.0         County Metro Area excluding MPLS/STP
# 4451            2.0         County Metro Area excluding MPLS/STP
# 4452            2.0         County Metro Area excluding MPLS/STP
# 4453            6.0          Outstate - Enrollment less than 500
# 4454            6.0          Outstate - Enrollment less than 500
#
# [4455 rows x 7 columns]

# %%
language_summary_2014_df = primary_home_language_2014_summary_df[primary_home_language_2014_summary_df["Strata Number"].isna()]
language_summary_2014_final_df = language_summary_2014_df.drop(columns = {"Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2014_final_df
# Out:
#     School Year District Name   Language Name  Home Primary Language  \
# 0         13-14     STATEWIDE            Igbo                     65
# 1         13-14     STATEWIDE          Ngumba                    408
# 2         13-14     STATEWIDE          German                     17
# 3         13-14     STATEWIDE        Gujarati                    112
# 4         13-14     STATEWIDE         Adangme                     83
# ..          ...           ...             ...                    ...
# 231       13-14     STATEWIDE           Tonga                    168
# 232       13-14     STATEWIDE         Marathi                    116
# 233       13-14     STATEWIDE         Palauan                    336
# 234       13-14     STATEWIDE           Dutch                     33
# 235       13-14     STATEWIDE  Haitian Creole                     85
#
#      Student Count
# 0              169
# 1                3
# 2              440
# 3              109
# 4              127
# ..             ...
# 231              4
# 232             67
# 233              1
# 234             85
# 235             37
#
# [236 rows x 5 columns]

# %%
primary_home_language_2015 = "data/2014-2015 Primary Home Language Totals.csv"
primary_home_language_2015_df = pd.read_csv(primary_home_language_2015)
primary_home_language_2015_rename_df = primary_home_language_2015_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name", "homePrimaryLanguage" : "Home Primary Language", "enrollments" : "Student Count", "Country Name" : "Country Name", "strata" : "Strata Number", "strataName" : "Strata Name"})
primary_home_language_2015_summary_df = primary_home_language_2015_rename_df.drop(columns = {"submissionCode", "districtType", "districtNumber", "countyCode", "CountyName", "eco_dev_rgn"})
primary_home_language_2015_summary_df
# Out:
#      School Year                    District Name        Language Name  \
# 0          14-15    AITKIN PUBLIC SCHOOL DISTRICT              English
# 1          14-15  MINNEAPOLIS PUBLIC SCHOOL DIST.              Swedish
# 2          14-15  MINNEAPOLIS PUBLIC SCHOOL DIST.  Swahili, Kiswahili
# 3          14-15  MINNEAPOLIS PUBLIC SCHOOL DIST.               Arabic
# 4          14-15  MINNEAPOLIS PUBLIC SCHOOL DIST.              Bosnian
# ...          ...                              ...                  ...
# 4790       14-15                        STATEWIDE              Faroese
# 4791       14-15                        STATEWIDE             Assamese
# 4792       14-15                        STATEWIDE               Breton
# 4793       14-15                        STATEWIDE                Hmong
# 4794       14-15                        STATEWIDE               Samoan
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                        11           1184            4.0
# 1                        46              4            1.0
# 2                        70             11            1.0
# 3                         2             52            1.0
# 4                        41             10            1.0
# ...                     ...            ...            ...
# 4790                    230              1            NaN
# 4791                    182              9            NaN
# 4792                    201              1            NaN
# 4793                     20          19889            NaN
# 4794                     56             30            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1                      Minneapolis and Saint Paul
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4790                                          NaN
# 4791                                          NaN
# 4792                                          NaN
# 4793                                          NaN
# 4794                                          NaN
#
# [4795 rows x 7 columns]

# %%
primary_home_language_2015_final_df = primary_home_language_2015_summary_df[~primary_home_language_2015_summary_df["Strata Number"].isna()]
primary_home_language_2015_final_df
# Out:
#      School Year                     District Name        Language Name  \
# 0          14-15     AITKIN PUBLIC SCHOOL DISTRICT              English
# 1          14-15   MINNEAPOLIS PUBLIC SCHOOL DIST.              Swedish
# 2          14-15   MINNEAPOLIS PUBLIC SCHOOL DIST.  Swahili, Kiswahili
# 3          14-15   MINNEAPOLIS PUBLIC SCHOOL DIST.               Arabic
# 4          14-15   MINNEAPOLIS PUBLIC SCHOOL DIST.              Bosnian
# ...          ...                               ...                  ...
# 4552       14-15  SOUTHWEST METRO EDUCATIONAL COOP              Spanish
# 4553       14-15  SOUTHWEST METRO EDUCATIONAL COOP              English
# 4554       14-15  SOUTHWEST METRO EDUCATIONAL COOP        Lao, Laotian
# 4555       14-15       BENTON-STEARNS ED. DISTRICT              English
# 4556       14-15      MID STATE EDUCATION DISTRICT              English
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                        11           1184            4.0
# 1                        46              4            1.0
# 2                        70             11            1.0
# 3                         2             52            1.0
# 4                        41             10            1.0
# ...                     ...            ...            ...
# 4552                     45             27            2.0
# 4553                     11            204            2.0
# 4554                     28              1            2.0
# 4555                     11             42            6.0
# 4556                     11             35            6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1                      Minneapolis and Saint Paul
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4552         County Metro Area excluding MPLS/STP
# 4553         County Metro Area excluding MPLS/STP
# 4554         County Metro Area excluding MPLS/STP
# 4555          Outstate - Enrollment less than 500
# 4556          Outstate - Enrollment less than 500
#
# [4557 rows x 7 columns]

# %%
language_summary_2015_df = primary_home_language_2015_summary_df[primary_home_language_2015_summary_df["Strata Number"].isna()]
language_summary_2015_final_df = language_summary_2015_df.drop(columns = {"Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2015_final_df
# Out:
#     School Year District Name      Language Name  Home Primary Language  \
# 0         14-15     STATEWIDE  Sarakole, Soninke                    355
# 1         14-15     STATEWIDE          Malayalam                    115
# 2         14-15     STATEWIDE              Belle                    195
# 3         14-15     STATEWIDE            Slovene                     44
# 4         14-15     STATEWIDE          Icelandic                     22
# ..          ...           ...                ...                    ...
# 233       14-15     STATEWIDE            Faroese                    230
# 234       14-15     STATEWIDE           Assamese                    182
# 235       14-15     STATEWIDE             Breton                    201
# 236       14-15     STATEWIDE              Hmong                     20
# 237       14-15     STATEWIDE             Samoan                     56
#
#      Student Count
# 0               11
# 1              126
# 2                1
# 3                4
# 4               10
# ..             ...
# 233              1
# 234              9
# 235              1
# 236          19889
# 237             30
#
# [238 rows x 5 columns]

# %%
primary_home_language_2016 = "data/2015-2016 Primary Home Language Totals.csv"
primary_home_language_2016_df = pd.read_csv(primary_home_language_2016)
primary_home_language_2016_rename_df = primary_home_language_2016_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name", "homePrimaryLanguage" : "Home Primary Language", "enrollments" : "Student Count", "Country Name" : "Country Name", "strata" : "Strata Number", "strataName" : "Strata Name"})
primary_home_language_2016_summary_df = primary_home_language_2016_rename_df.drop(columns = {"submissionCode", "districtType", "districtNumber", "countyCode", "CountyName", "eco_dev_rgn"})
primary_home_language_2016_summary_df
# Out:
#      School Year                    District Name        Language Name  \
# 0          15-16    AITKIN PUBLIC SCHOOL DISTRICT              English
# 1          15-16  MINNEAPOLIS PUBLIC SCHOOL DIST.  Swahili, Kiswahili
# 2          15-16  MINNEAPOLIS PUBLIC SCHOOL DIST.                Czech
# 3          15-16  MINNEAPOLIS PUBLIC SCHOOL DIST.              Spanish
# 4          15-16  MINNEAPOLIS PUBLIC SCHOOL DIST.             Romanian
# ...          ...                              ...                  ...
# 5005       15-16                        STATEWIDE             Estonian
# 5006       15-16                        STATEWIDE                Tigre
# 5007       15-16                        STATEWIDE              Latvian
# 5008       15-16                        STATEWIDE                Czech
# 5009         NaN                              NaN                  NaN
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                      11.0         1187.0            4.0
# 1                      70.0           15.0            1.0
# 2                       4.0            2.0            1.0
# 3                      45.0         5435.0            1.0
# 4                      39.0            2.0            1.0
# ...                     ...            ...            ...
# 5005                   12.0           30.0            NaN
# 5006                  145.0           16.0            NaN
# 5007                   29.0           27.0            NaN
# 5008                    4.0           19.0            NaN
# 5009                    NaN            NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1                      Minneapolis and Saint Paul
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5005                                          NaN
# 5006                                          NaN
# 5007                                          NaN
# 5008                                          NaN
# 5009                                          NaN
#
# [5010 rows x 7 columns]

# %%
primary_home_language_2016_final_df = primary_home_language_2016_summary_df[~primary_home_language_2016_summary_df["Strata Number"].isna()]
primary_home_language_2016_final_df
# Out:
#      School Year                        District Name        Language Name  \
# 0          15-16        AITKIN PUBLIC SCHOOL DISTRICT              English
# 1          15-16      MINNEAPOLIS PUBLIC SCHOOL DIST.  Swahili, Kiswahili
# 2          15-16      MINNEAPOLIS PUBLIC SCHOOL DIST.                Czech
# 3          15-16      MINNEAPOLIS PUBLIC SCHOOL DIST.              Spanish
# 4          15-16      MINNEAPOLIS PUBLIC SCHOOL DIST.             Romanian
# ...          ...                                  ...                  ...
# 4754       15-16  SHERBURNE AND NORTHERN WRIGHT SPECI               Korean
# 4755       15-16  SHERBURNE AND NORTHERN WRIGHT SPECI  Swahili, Kiswahili
# 4756       15-16  SHERBURNE AND NORTHERN WRIGHT SPECI              English
# 4757       15-16          BENTON-STEARNS ED. DISTRICT              English
# 4758       15-16         MID STATE EDUCATION DISTRICT              English
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                      11.0         1187.0            4.0
# 1                      70.0           15.0            1.0
# 2                       4.0            2.0            1.0
# 3                      45.0         5435.0            1.0
# 4                      39.0            2.0            1.0
# ...                     ...            ...            ...
# 4754                   26.0            1.0            6.0
# 4755                   70.0            1.0            6.0
# 4756                   11.0           87.0            6.0
# 4757                   11.0           49.0            6.0
# 4758                   11.0           42.0            6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1                      Minneapolis and Saint Paul
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4754          Outstate - Enrollment less than 500
# 4755          Outstate - Enrollment less than 500
# 4756          Outstate - Enrollment less than 500
# 4757          Outstate - Enrollment less than 500
# 4758          Outstate - Enrollment less than 500
#
# [4759 rows x 7 columns]

# %%
language_summary_2016_df = primary_home_language_2016_summary_df[primary_home_language_2016_summary_df["Strata Number"].isna()]
language_summary_2016_final_df = language_summary_2016_df.drop(columns = {"Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2016_final_df
# Out:
#     School Year District Name Language Name  Home Primary Language  \
# 0         15-16     STATEWIDE       Bengali                   10.0
# 1         15-16     STATEWIDE       Finnish                   14.0
# 2         15-16     STATEWIDE      Wolaytta                  396.0
# 3         15-16     STATEWIDE      Georgian                   82.0
# 4         15-16     STATEWIDE       Sinhala                   58.0
# ..          ...           ...           ...                    ...
# 246       15-16     STATEWIDE      Estonian                   12.0
# 247       15-16     STATEWIDE         Tigre                  145.0
# 248       15-16     STATEWIDE       Latvian                   29.0
# 249       15-16     STATEWIDE         Czech                    4.0
# 250         NaN           NaN           NaN                    NaN
#
#      Student Count
# 0            725.0
# 1             62.0
# 2              3.0
# 3             11.0
# 4             24.0
# ..             ...
# 246           30.0
# 247           16.0
# 248           27.0
# 249           19.0
# 250            NaN
#
# [251 rows x 5 columns]

# %%
primary_home_language_2017 = "data/2016-2017 Primary Home Language Totals.csv"
primary_home_language_2017_df = pd.read_csv(primary_home_language_2017)
primary_home_language_2017_rename_df = primary_home_language_2017_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name", "homePrimaryLanguage" : "Home Primary Language", "enrollments" : "Student Count", "Country Name" : "Country Name", "strata" : "Strata Number", "strataName" : "Strata Name"})
primary_home_language_2017_summary_df = primary_home_language_2017_rename_df.drop(columns = {"submissionCode", "districtType", "districtNumber", "countyCode", "CountyName", "eco_dev_rgn"})
primary_home_language_2017_summary_df
# Out:
#      School Year                       District Name Language Name  \
# 0          16-17       AITKIN PUBLIC SCHOOL DISTRICT        Arabic
# 1          16-17       AITKIN PUBLIC SCHOOL DISTRICT       English
# 2          16-17  Minneapolis Public School District            Ga
# 3          16-17  Minneapolis Public School District       Bengali
# 4          16-17  Minneapolis Public School District         Krahn
# ...          ...                                 ...           ...
# 5172       16-17                           STATEWIDE        Anaang
# 5173       16-17                           STATEWIDE       Bengali
# 5174       16-17                           STATEWIDE       Konkani
# 5175       16-17                           STATEWIDE      Croatian
# 5176         NaN                                 NaN           NaN
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                       2.0            2.0            4.0
# 1                      11.0         1142.0            4.0
# 2                     160.0            2.0            1.0
# 3                      10.0           28.0            1.0
# 4                     281.0            1.0            1.0
# ...                     ...            ...            ...
# 5172                  179.0            1.0            NaN
# 5173                   10.0          662.0            NaN
# 5174                  114.0           13.0            NaN
# 5175                  127.0           14.0            NaN
# 5176                    NaN            NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5172                                          NaN
# 5173                                          NaN
# 5174                                          NaN
# 5175                                          NaN
# 5176                                          NaN
#
# [5177 rows x 7 columns]

# %%
primary_home_language_2017_final_df = primary_home_language_2017_summary_df[~primary_home_language_2017_summary_df["Strata Number"].isna()]
primary_home_language_2017_final_df
# Out:
#      School Year                        District Name Language Name  \
# 0          16-17        AITKIN PUBLIC SCHOOL DISTRICT        Arabic
# 1          16-17        AITKIN PUBLIC SCHOOL DISTRICT       English
# 2          16-17   Minneapolis Public School District            Ga
# 3          16-17   Minneapolis Public School District       Bengali
# 4          16-17   Minneapolis Public School District         Krahn
# ...          ...                                  ...           ...
# 4919       16-17  Cannon Valley Special Education Coo       English
# 4920       16-17  Austin Albert Lea Area Special Educ       Spanish
# 4921       16-17  Austin Albert Lea Area Special Educ       English
# 4922       16-17          BENTON-STEARNS ED. DISTRICT       English
# 4923       16-17         MID STATE EDUCATION DISTRICT       English
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                       2.0            2.0            4.0
# 1                      11.0         1142.0            4.0
# 2                     160.0            2.0            1.0
# 3                      10.0           28.0            1.0
# 4                     281.0            1.0            1.0
# ...                     ...            ...            ...
# 4919                   11.0           75.0            6.0
# 4920                   45.0            3.0            6.0
# 4921                   11.0           39.0            6.0
# 4922                   11.0           44.0            6.0
# 4923                   11.0           40.0            6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2                      Minneapolis and Saint Paul
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 4919          Outstate - Enrollment less than 500
# 4920          Outstate - Enrollment less than 500
# 4921          Outstate - Enrollment less than 500
# 4922          Outstate - Enrollment less than 500
# 4923          Outstate - Enrollment less than 500
#
# [4924 rows x 7 columns]

# %%
language_summary_2017_df = primary_home_language_2017_summary_df[primary_home_language_2017_summary_df["Strata Number"].isna()]
language_summary_2017_final_df = language_summary_2017_df.drop(columns = {"Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2017_final_df
# Out:
#     School Year District Name Language Name  Home Primary Language  \
# 0         16-17     STATEWIDE        Karen                   129.0
# 1         16-17     STATEWIDE       Russian                   40.0
# 2         16-17     STATEWIDE    Mano. Mah                   297.0
# 3         16-17     STATEWIDE        Arabic                    2.0
# 4         16-17     STATEWIDE       Nyanga                   167.0
# ..          ...           ...           ...                    ...
# 248       16-17     STATEWIDE        Anaang                  179.0
# 249       16-17     STATEWIDE       Bengali                   10.0
# 250       16-17     STATEWIDE       Konkani                  114.0
# 251       16-17     STATEWIDE      Croatian                  127.0
# 252         NaN           NaN           NaN                    NaN
#
#      Student Count
# 0           3644.0
# 1           2464.0
# 2              8.0
# 3           2842.0
# 4              2.0
# ..             ...
# 248            1.0
# 249          662.0
# 250           13.0
# 251           14.0
# 252            NaN
#
# [253 rows x 5 columns]

# %%
primary_home_language_2018 = "data/2017-18 Primary Home Language Totals.csv"
primary_home_language_2018_df = pd.read_csv(primary_home_language_2018)
primary_home_language_2018_rename_df = primary_home_language_2018_df.rename(columns = {"Fiscal Year" : "School Year", "Strata" : "Strata Number", "Enrollments" : "Student Count"})
primary_home_language_2018_summary_df =  primary_home_language_2018_rename_df.drop(columns  = {"Submission Code", "District Number","District Type", "County Code", "Economic Development Region"})
primary_home_language_2018_summary_df
# Out:
#      School Year                       District Name        Language Name  \
# 0          17-18       Aitkin Public School District               Arabic
# 1          17-18       Aitkin Public School District              English
# 2          17-18  Minneapolis Public School District                Tamil
# 3          17-18  Minneapolis Public School District  Swahili, Kiswahili
# 4          17-18  Minneapolis Public School District                 Maay
# ...          ...                                 ...                  ...
# 5423       17-18                          Statewide                Ngumba
# 5424       17-18                          Statewide              Cherokee
# 5425       17-18                          Statewide              Kwanyama
# 5426         NaN                                 NaN                  NaN
# 5427         NaN                                 NaN                  NaN
#
#       Home Primary Language  Student Count  \
# 0                       2.0            2.0
# 1                      11.0         1160.0
# 2                     118.0            5.0
# 3                      70.0           15.0
# 4                     100.0            1.0
# ...                     ...            ...
# 5423                  408.0            6.0
# 5424                  207.0            1.0
# 5425                  285.0            1.0
# 5426                    NaN            NaN
# 5427                    NaN            NaN
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 5423                                            NaN            NaN
# 5424                                            NaN            NaN
# 5425                                            NaN            NaN
# 5426                                            NaN            NaN
# 5427                                            NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2           Minneapolis and Saint Paul (MPLS/STP)
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5423                                          NaN
# 5424                                          NaN
# 5425                                          NaN
# 5426                                          NaN
# 5427                                          NaN
#
# [5428 rows x 8 columns]

# %%
primary_home_language_2018_final_df = primary_home_language_2018_summary_df[~primary_home_language_2018_summary_df["Strata Number"].isna()]
primary_home_language_2018_final_df
# Out:
#      School Year                                      District Name  \
# 0          17-18                      Aitkin Public School District
# 1          17-18                      Aitkin Public School District
# 2          17-18                 Minneapolis Public School District
# 3          17-18                 Minneapolis Public School District
# 4          17-18                 Minneapolis Public School District
# ...          ...                                                ...
# 5160       17-18  Austin Albert Lea Area Special Education Coope...
# 5161       17-18  Austin Albert Lea Area Special Education Coope...
# 5162       17-18                Northern Lights Academy Cooperative
# 5163       17-18                  Benton-Stearns Education District
# 5164       17-18                       Mid State Education District
#
#             Language Name  Home Primary Language  Student Count  \
# 0                  Arabic                    2.0            2.0
# 1                 English                   11.0         1160.0
# 2                   Tamil                  118.0            5.0
# 3     Swahili, Kiswahili                    70.0           15.0
# 4                    Maay                  100.0            1.0
# ...                   ...                    ...            ...
# 5160              English                   11.0           50.0
# 5161              Spanish                   45.0            2.0
# 5162              English                   11.0           16.0
# 5163              English                   11.0           51.0
# 5164              English                   11.0           47.0
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Hennepin                                                 1.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 5160  Mower                                                    6.0
# 5161  Mower                                                    6.0
# 5162  Carlton                                                  6.0
# 5163  Stearns                                                  6.0
# 5164  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2           Minneapolis and Saint Paul (MPLS/STP)
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5160          Outstate - Enrollment less than 500
# 5161          Outstate - Enrollment less than 500
# 5162          Outstate - Enrollment less than 500
# 5163          Outstate - Enrollment less than 500
# 5164          Outstate - Enrollment less than 500
#
# [5165 rows x 8 columns]

# %%
language_summary_2018_df = primary_home_language_2018_summary_df[primary_home_language_2018_summary_df["Strata Number"].isna()]
language_summary_2018_final_df = language_summary_2018_df.drop(columns = {"County Name", "Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2018_final_df
# Out:
#     School Year District Name                               Language Name  \
# 0         17-18    Statewide                        Portuguese, creolized
# 1         17-18    Statewide                                     Kalenjin
# 2         17-18    Statewide   Tem, Cocotoli (Kokotoli), Temba, Tim, Timu
# 3         17-18    Statewide                                     Okinawan
# 4         17-18    Statewide                                        Khasi
# ..          ...           ...                                         ...
# 258       17-18    Statewide                                       Ngumba
# 259       17-18    Statewide                                     Cherokee
# 260       17-18    Statewide                                     Kwanyama
# 261         NaN           NaN                                         NaN
# 262         NaN           NaN                                         NaN
#
#      Home Primary Language  Student Count
# 0                    342.0            4.0
# 1                    260.0            5.0
# 2                    421.0            4.0
# 3                    123.0            3.0
# 4                    268.0            1.0
# ..                     ...            ...
# 258                  408.0            6.0
# 259                  207.0            1.0
# 260                  285.0            1.0
# 261                    NaN            NaN
# 262                    NaN            NaN
#
# [263 rows x 5 columns]

# %%
primary_home_language_2019 = "data/2018-19 Primary Home Language Totals.csv"
primary_home_language_2019_df = pd.read_csv(primary_home_language_2019)
primary_home_language_2019_rename_df = primary_home_language_2019_df.rename(columns = {"fiscalYear" : "School Year", "districtName" : "District Name", "languageName" : "Language Name", "homePrimaryLanguage" : "Home Primary Language", "enrollments" : "Student Count", "Country Name" : "Country Name", "strata" : "Strata Number", "strataName" : "Strata Name"})
primary_home_language_2019_summary_df = primary_home_language_2019_rename_df.drop(columns = {"submissionCode", "districtType", "districtNumber", "countyCode", "CountyName", "eco_dev_rgn"})
primary_home_language_2019_summary_df
# Out:
#      School Year                       District Name   Language Name  \
# 0          18-19       AITKIN PUBLIC SCHOOL DISTRICT         Spanish
# 1          18-19       AITKIN PUBLIC SCHOOL DISTRICT          Arabic
# 2          18-19       AITKIN PUBLIC SCHOOL DISTRICT          German
# 3          18-19       AITKIN PUBLIC SCHOOL DISTRICT         English
# 4          18-19  Minneapolis Public School District          Yoruba
# ...          ...                                 ...             ...
# 5697       18-19                           STATEWIDE  Haitian Creole
# 5698       18-19                           STATEWIDE         Bosnian
# 5699       18-19                           STATEWIDE          Dakota
# 5700       18-19                           STATEWIDE        Kashmiri
# 5701         NaN                                 NaN             NaN
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                      45.0            1.0            4.0
# 1                       2.0            2.0            4.0
# 2                      17.0            3.0            4.0
# 3                      11.0         1163.0            4.0
# 4                      75.0            3.0            1.0
# ...                     ...            ...            ...
# 5697                   85.0           53.0            NaN
# 5698                   41.0          427.0            NaN
# 5699                    8.0           50.0            NaN
# 5700                  265.0            2.0            NaN
# 5701                    NaN            NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3     Outstate - Enrollment between 1000 and 1999
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5697                                          NaN
# 5698                                          NaN
# 5699                                          NaN
# 5700                                          NaN
# 5701                                          NaN
#
# [5702 rows x 7 columns]

# %%
primary_home_language_2019_final_df = primary_home_language_2019_summary_df[~primary_home_language_2019_summary_df["Strata Number"].isna()]
primary_home_language_2019_final_df
# Out:
#      School Year                        District Name Language Name  \
# 0          18-19        AITKIN PUBLIC SCHOOL DISTRICT       Spanish
# 1          18-19        AITKIN PUBLIC SCHOOL DISTRICT        Arabic
# 2          18-19        AITKIN PUBLIC SCHOOL DISTRICT        German
# 3          18-19        AITKIN PUBLIC SCHOOL DISTRICT       English
# 4          18-19   Minneapolis Public School District        Yoruba
# ...          ...                                  ...           ...
# 5397       18-19  Austin Albert Lea Area Special Educ       Spanish
# 5398       18-19  Austin Albert Lea Area Special Educ       English
# 5399       18-19  Northern Lights Academy Cooperative       English
# 5400       18-19          BENTON-STEARNS ED. DISTRICT       English
# 5401       18-19         MID STATE EDUCATION DISTRICT       English
#
#       Home Primary Language  Student Count  Strata Number  \
# 0                      45.0            1.0            4.0
# 1                       2.0            2.0            4.0
# 2                      17.0            3.0            4.0
# 3                      11.0         1163.0            4.0
# 4                      75.0            3.0            1.0
# ...                     ...            ...            ...
# 5397                   45.0            2.0            6.0
# 5398                   11.0           46.0            6.0
# 5399                   11.0           23.0            6.0
# 5400                   11.0           54.0            6.0
# 5401                   11.0           40.0            6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3     Outstate - Enrollment between 1000 and 1999
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5397          Outstate - Enrollment less than 500
# 5398          Outstate - Enrollment less than 500
# 5399          Outstate - Enrollment less than 500
# 5400          Outstate - Enrollment less than 500
# 5401          Outstate - Enrollment less than 500
#
# [5402 rows x 7 columns]

# %%
language_summary_2019_df = primary_home_language_2019_summary_df[primary_home_language_2019_summary_df["Strata Number"].isna()]
language_summary_2019_final_df = language_summary_2019_df.drop(columns = {"Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2019_final_df
# Out:
#     School Year District Name   Language Name  Home Primary Language  \
# 0         18-19     STATEWIDE             Mon                  316.0
# 1         18-19     STATEWIDE            Igbo                   65.0
# 2         18-19     STATEWIDE          Udmurt                  382.0
# 3         18-19     STATEWIDE           Bemba                   98.0
# 4         18-19     STATEWIDE         Kabyle                    78.0
# ..          ...           ...             ...                    ...
# 295       18-19     STATEWIDE  Haitian Creole                   85.0
# 296       18-19     STATEWIDE         Bosnian                   41.0
# 297       18-19     STATEWIDE          Dakota                    8.0
# 298       18-19     STATEWIDE        Kashmiri                  265.0
# 299         NaN           NaN             NaN                    NaN
#
#      Student Count
# 0             28.0
# 1            163.0
# 2              1.0
# 3              2.0
# 4              8.0
# ..             ...
# 295           53.0
# 296          427.0
# 297           50.0
# 298            2.0
# 299            NaN
#
# [300 rows x 5 columns]

# %%
primary_home_language_2020 = "data/2019-20 Primary Home Language Totals.csv"
primary_home_language_2020_df = pd.read_csv(primary_home_language_2020)
primary_home_language_2020_rename_df = primary_home_language_2020_df.rename(columns = {"Fiscal Year" : "School Year", "Strata" : "Strata Number", "Enrollments" : "Student Count"})
primary_home_language_2020_summary_df =  primary_home_language_2020_rename_df.drop(columns  = {"Submission Code", "District Number","District Type", "County Code", "Economic Development Region"})
primary_home_language_2020_summary_df
# Out:
#      School Year                  District Name  \
# 0          19-20  Aitkin Public School District
# 1          19-20  Aitkin Public School District
# 2          19-20  Aitkin Public School District
# 3          19-20  Aitkin Public School District
# 4          19-20  Aitkin Public School District
# ...          ...                            ...
# 5963       19-20                     Statewide
# 5964       19-20                     Statewide
# 5965       19-20                     Statewide
# 5966         NaN                            NaN
# 5967         NaN                            NaN
#
#                            Language Name  Home Primary Language  \
# 0                                Italian                   23.0
# 1     Serbian, Herzegovnian, Montenegrin                  128.0
# 2                                English                   11.0
# 3                                 Arabic                    2.0
# 4                                 Bisaya                  417.0
# ...                                  ...                    ...
# 5963                               Bugis                  202.0
# 5964                             Palauan                  336.0
# 5965                           Pahlavani                  335.0
# 5966                                 NaN                    NaN
# 5967                                 NaN                    NaN
#
#       Student Count                                    County Name  \
# 0               1.0  Aitkin
# 1               1.0  Aitkin
# 2            1149.0  Aitkin
# 3               2.0  Aitkin
# 4               1.0  Aitkin
# ...             ...                                            ...
# 5963            1.0                                            NaN
# 5964            8.0                                            NaN
# 5965            2.0                                            NaN
# 5966            NaN                                            NaN
# 5967            NaN                                            NaN
#
#       Strata Number                                  Strata Name
# 0               4.0  Outstate - Enrollment between 1000 and 1999
# 1               4.0  Outstate - Enrollment between 1000 and 1999
# 2               4.0  Outstate - Enrollment between 1000 and 1999
# 3               4.0  Outstate - Enrollment between 1000 and 1999
# 4               4.0  Outstate - Enrollment between 1000 and 1999
# ...             ...                                          ...
# 5963            NaN                                          NaN
# 5964            NaN                                          NaN
# 5965            NaN                                          NaN
# 5966            NaN                                          NaN
# 5967            NaN                                          NaN
#
# [5968 rows x 8 columns]

# %%
primary_home_language_2020_final_df = primary_home_language_2020_summary_df[~primary_home_language_2020_summary_df["Strata Number"].isna()]
primary_home_language_2020_final_df
# Out:
#      School Year                                      District Name  \
# 0          19-20                      Aitkin Public School District
# 1          19-20                      Aitkin Public School District
# 2          19-20                      Aitkin Public School District
# 3          19-20                      Aitkin Public School District
# 4          19-20                      Aitkin Public School District
# ...          ...                                                ...
# 5649       19-20  Austin Albert Lea Area Special Education Coope...
# 5650       19-20  Austin Albert Lea Area Special Education Coope...
# 5651       19-20                Northern Lights Academy Cooperative
# 5652       19-20                  Benton-Stearns Education District
# 5653       19-20                       Mid State Education District
#
#                            Language Name  Home Primary Language  \
# 0                                Italian                   23.0
# 1     Serbian, Herzegovnian, Montenegrin                  128.0
# 2                                English                   11.0
# 3                                 Arabic                    2.0
# 4                                 Bisaya                  417.0
# ...                                  ...                    ...
# 5649                             English                   11.0
# 5650                             Spanish                   45.0
# 5651                             English                   11.0
# 5652                             English                   11.0
# 5653                             English                   11.0
#
#       Student Count                                    County Name  \
# 0               1.0  Aitkin
# 1               1.0  Aitkin
# 2            1149.0  Aitkin
# 3               2.0  Aitkin
# 4               1.0  Aitkin
# ...             ...                                            ...
# 5649           34.0  Mower
# 5650            1.0  Mower
# 5651           29.0  Carlton
# 5652           58.0  Stearns
# 5653           50.0  Morrison
#
#       Strata Number                                  Strata Name
# 0               4.0  Outstate - Enrollment between 1000 and 1999
# 1               4.0  Outstate - Enrollment between 1000 and 1999
# 2               4.0  Outstate - Enrollment between 1000 and 1999
# 3               4.0  Outstate - Enrollment between 1000 and 1999
# 4               4.0  Outstate - Enrollment between 1000 and 1999
# ...             ...                                          ...
# 5649            6.0          Outstate - Enrollment less than 500
# 5650            6.0          Outstate - Enrollment less than 500
# 5651            6.0          Outstate - Enrollment less than 500
# 5652            6.0          Outstate - Enrollment less than 500
# 5653            6.0          Outstate - Enrollment less than 500
#
# [5654 rows x 8 columns]

# %%
language_summary_2020_df = primary_home_language_2020_summary_df[primary_home_language_2020_summary_df["Strata Number"].isna()]
language_summary_2020_final_df = language_summary_2020_df.drop(columns = {"County Name", "Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2020_final_df
# Out:
#     School Year District Name Language Name  Home Primary Language  \
# 0         19-20    Statewide        Quichua                  170.0
# 1         19-20    Statewide        Guarani                  153.0
# 2         19-20    Statewide          Duala                  224.0
# 3         19-20    Statewide         Mandar                  301.0
# 4         19-20    Statewide           Maay                  100.0
# ..          ...           ...           ...                    ...
# 309       19-20    Statewide          Bugis                  202.0
# 310       19-20    Statewide        Palauan                  336.0
# 311       19-20    Statewide      Pahlavani                  335.0
# 312         NaN           NaN           NaN                    NaN
# 313         NaN           NaN           NaN                    NaN
#
#      Student Count
# 0             50.0
# 1              3.0
# 2              5.0
# 3              6.0
# 4              6.0
# ..             ...
# 309            1.0
# 310            8.0
# 311            2.0
# 312            NaN
# 313            NaN
#
# [314 rows x 5 columns]

# %%
primary_home_language_2021 = "data/2020-21 Primary Home Language Totals.csv"
primary_home_language_2021_df = pd.read_csv(primary_home_language_2021)
primary_home_language_2021_rename_df = primary_home_language_2021_df.rename(columns = {"Fiscal Year" : "School Year", "Strata" : "Strata Number", "Enrollments" : "Student Count"})
primary_home_language_2021_summary_df =  primary_home_language_2021_rename_df.drop(columns  = {"Submission Code", "District Number","District Type", "County Code", "Economic Development Region"})
primary_home_language_2021_summary_df
# Out:
#      School Year                       District Name      Language Name  \
# 0          20-21       AITKIN PUBLIC SCHOOL DISTRICT             Bisaya
# 1          20-21       AITKIN PUBLIC SCHOOL DISTRICT             Arabic
# 2          20-21       AITKIN PUBLIC SCHOOL DISTRICT            English
# 3          20-21  Minneapolis Public School District           Sarakole
# 4          20-21  Minneapolis Public School District  Khmer, Cambodian
# ...          ...                                 ...                ...
# 6020       20-21                           STATEWIDE          Abkhazian
# 6021       20-21                           STATEWIDE               Shan
# 6022       20-21                           STATEWIDE             Nyanja
# 6023         NaN                                 NaN                NaN
# 6024         NaN                                 NaN                NaN
#
#       Home Primary Language  Student Count  \
# 0                     417.0            1.0
# 1                       2.0            2.0
# 2                      11.0         1104.0
# 3                     355.0            1.0
# 4                       5.0           15.0
# ...                     ...            ...
# 6020                  171.0           10.0
# 6021                  130.0            4.0
# 6022                  330.0            4.0
# 6023                    NaN            NaN
# 6024                    NaN            NaN
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Aitkin                                                   4.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 6020                                                           NaN
# 6021                                                           NaN
# 6022                                                           NaN
# 6023                                            NaN            NaN
# 6024                                            NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 6020                                          NaN
# 6021                                          NaN
# 6022                                          NaN
# 6023                                          NaN
# 6024                                          NaN
#
# [6025 rows x 8 columns]

# %%
primary_home_language_2021_final_df = primary_home_language_2021_summary_df[~primary_home_language_2021_summary_df["Strata Number"].isna()]
primary_home_language_2021_final_df
# Out:
#      School Year                        District Name      Language Name  \
# 0          20-21        AITKIN PUBLIC SCHOOL DISTRICT             Bisaya
# 1          20-21        AITKIN PUBLIC SCHOOL DISTRICT             Arabic
# 2          20-21        AITKIN PUBLIC SCHOOL DISTRICT            English
# 3          20-21   Minneapolis Public School District           Sarakole
# 4          20-21   Minneapolis Public School District  Khmer, Cambodian
# ...          ...                                  ...                ...
# 5695       20-21  Austin Albert Lea Area Special Educ            English
# 5696       20-21  Austin Albert Lea Area Special Educ            Spanish
# 5697       20-21  Northern Lights Academy Cooperative            English
# 5698       20-21    Benton-Stearns Education District            English
# 5699       20-21         MID STATE EDUCATION DISTRICT            English
#
#       Home Primary Language  Student Count  \
# 0                     417.0            1.0
# 1                       2.0            2.0
# 2                      11.0         1104.0
# 3                     355.0            1.0
# 4                       5.0           15.0
# ...                     ...            ...
# 5695                   11.0           38.0
# 5696                   45.0            2.0
# 5697                   11.0           19.0
# 5698                   11.0           59.0
# 5699                   11.0           42.0
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Aitkin                                                   4.0
# 3     Hennepin                                                 1.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 5695  Mower                                                    6.0
# 5696  Mower                                                    6.0
# 5697  Carlton                                                  6.0
# 5698  Stearns                                                  6.0
# 5699  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3                      Minneapolis and Saint Paul
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5695          Outstate - Enrollment less than 500
# 5696          Outstate - Enrollment less than 500
# 5697          Outstate - Enrollment less than 500
# 5698          Outstate - Enrollment less than 500
# 5699          Outstate - Enrollment less than 500
#
# [5700 rows x 8 columns]

# %%
language_summary_2021_df = primary_home_language_2021_summary_df[primary_home_language_2021_summary_df["Strata Number"].isna()]
language_summary_2021_final_df = language_summary_2021_df.drop(columns = {"County Name", "Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2021_final_df
# Out:
#     School Year District Name Language Name  Home Primary Language  \
# 0         20-21     STATEWIDE       Quechua                   80.0
# 1         20-21     STATEWIDE         Saami                  350.0
# 2         20-21     STATEWIDE          Susu                  364.0
# 3         20-21     STATEWIDE        Anaang                  179.0
# 4         20-21     STATEWIDE         Erzya                  227.0
# ..          ...           ...           ...                    ...
# 320       20-21     STATEWIDE     Abkhazian                  171.0
# 321       20-21     STATEWIDE          Shan                  130.0
# 322       20-21     STATEWIDE        Nyanja                  330.0
# 323         NaN           NaN           NaN                    NaN
# 324         NaN           NaN           NaN                    NaN
#
#      Student Count
# 0             23.0
# 1             13.0
# 2              8.0
# 3              1.0
# 4              2.0
# ..             ...
# 320           10.0
# 321            4.0
# 322            4.0
# 323            NaN
# 324            NaN
#
# [325 rows x 5 columns]

# %%
primary_home_language_2022 = "data/2021-22 Primary Home Language Totals.csv"
primary_home_language_2022_df = pd.read_csv(primary_home_language_2022)
primary_home_language_2022_rename_df = primary_home_language_2022_df.rename(columns = {"Fiscal Year" : "School Year", "Strata" : "Strata Number", "Enrollments" : "Student Count"})
primary_home_language_2022_summary_df =  primary_home_language_2022_rename_df.drop(columns  = {"Submission Code", "District Number","District Type", "County Code", "Economic Development Region"})
primary_home_language_2022_summary_df
# Out:
#      School Year                       District Name Language Name  \
# 0          21-22       AITKIN PUBLIC SCHOOL DISTRICT        Arabic
# 1          21-22       AITKIN PUBLIC SCHOOL DISTRICT       English
# 2          21-22       AITKIN PUBLIC SCHOOL DISTRICT      Estonian
# 3          21-22       AITKIN PUBLIC SCHOOL DISTRICT        Bisaya
# 4          21-22  Minneapolis Public School District     Afrikaans
# ...          ...                                 ...           ...
# 6285       21-22                           STATEWIDE        Dagari
# 6286       21-22                           STATEWIDE      Chukeese
# 6287       21-22                           STATEWIDE         Eleme
# 6288         NaN                                 NaN           NaN
# 6289         NaN                                 NaN           NaN
#
#       Home Primary Language  Student Count  \
# 0                       2.0            2.0
# 1                      11.0         1038.0
# 2                      12.0            2.0
# 3                     417.0            1.0
# 4                       1.0            3.0
# ...                     ...            ...
# 6285                  443.0            1.0
# 6286                  444.0            1.0
# 6287                  447.0            1.0
# 6288                    NaN            NaN
# 6289                    NaN            NaN
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Aitkin                                                   4.0
# 3     Aitkin                                                   4.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 6285                                                           NaN
# 6286                                                           NaN
# 6287                                                           NaN
# 6288                                            NaN            NaN
# 6289                                            NaN            NaN
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3     Outstate - Enrollment between 1000 and 1999
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 6285                                          NaN
# 6286                                          NaN
# 6287                                          NaN
# 6288                                          NaN
# 6289                                          NaN
#
# [6290 rows x 8 columns]

# %%
primary_home_language_2022_final_df = primary_home_language_2022_summary_df[~primary_home_language_2022_summary_df["Strata Number"].isna()]
primary_home_language_2022_final_df
# Out:
#      School Year                        District Name Language Name  \
# 0          21-22        AITKIN PUBLIC SCHOOL DISTRICT        Arabic
# 1          21-22        AITKIN PUBLIC SCHOOL DISTRICT       English
# 2          21-22        AITKIN PUBLIC SCHOOL DISTRICT      Estonian
# 3          21-22        AITKIN PUBLIC SCHOOL DISTRICT        Bisaya
# 4          21-22   Minneapolis Public School District     Afrikaans
# ...          ...                                  ...           ...
# 5939       21-22  Austin Albert Lea Area Special Educ        Karen
# 5940       21-22  Northern Lights Academy Cooperative       English
# 5941       21-22             Up North Learning Center       English
# 5942       21-22    Benton-Stearns Education District       English
# 5943       21-22         MID STATE EDUCATION DISTRICT       English
#
#       Home Primary Language  Student Count  \
# 0                       2.0            2.0
# 1                      11.0         1038.0
# 2                      12.0            2.0
# 3                     417.0            1.0
# 4                       1.0            3.0
# ...                     ...            ...
# 5939                  129.0            1.0
# 5940                   11.0           27.0
# 5941                   11.0            5.0
# 5942                   11.0           58.0
# 5943                   11.0           40.0
#
#                                         County Name  Strata Number  \
# 0     Aitkin                                                   4.0
# 1     Aitkin                                                   4.0
# 2     Aitkin                                                   4.0
# 3     Aitkin                                                   4.0
# 4     Hennepin                                                 1.0
# ...                                             ...            ...
# 5939  Mower                                                    6.0
# 5940  Carlton                                                  6.0
# 5941  Cass                                                     6.0
# 5942  Stearns                                                  6.0
# 5943  Morrison                                                 6.0
#
#                                       Strata Name
# 0     Outstate - Enrollment between 1000 and 1999
# 1     Outstate - Enrollment between 1000 and 1999
# 2     Outstate - Enrollment between 1000 and 1999
# 3     Outstate - Enrollment between 1000 and 1999
# 4                      Minneapolis and Saint Paul
# ...                                           ...
# 5939          Outstate - Enrollment less than 500
# 5940          Outstate - Enrollment less than 500
# 5941          Outstate - Enrollment less than 500
# 5942          Outstate - Enrollment less than 500
# 5943          Outstate - Enrollment less than 500
#
# [5944 rows x 8 columns]

# %%
language_summary_2022_df = primary_home_language_2022_summary_df[primary_home_language_2022_summary_df["Strata Number"].isna()]
language_summary_2022_final_df = language_summary_2022_df.drop(columns = {"County Name", "Strata Number", "Strata Name"}).reset_index(drop=True)
language_summary_2022_final_df
# Out:
#     School Year District Name      Language Name  Home Primary Language  \
# 0         21-22     STATEWIDE          Afrikaans                    1.0
# 1         21-22     STATEWIDE             Arabic                    2.0
# 2         21-22     STATEWIDE           Armenian                    3.0
# 3         21-22     STATEWIDE              Czech                    4.0
# 4         21-22     STATEWIDE  Khmer, Cambodian                     5.0
# ..          ...           ...                ...                    ...
# 341       21-22     STATEWIDE             Dagari                  443.0
# 342       21-22     STATEWIDE           Chukeese                  444.0
# 343       21-22     STATEWIDE              Eleme                  447.0
# 344         NaN           NaN                NaN                    NaN
# 345         NaN           NaN                NaN                    NaN
#
#      Student Count
# 0            165.0
# 1           3253.0
# 2             27.0
# 3             29.0
# 4           1329.0
# ..             ...
# 341            1.0
# 342            1.0
# 343            1.0
# 344            NaN
# 345            NaN
#
# [346 rows x 5 columns]

# %%
# Merge yearly dataframes

# %%
# Merge summary dataframes
